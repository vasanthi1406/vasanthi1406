# %%
from sklearn.datasets import load_iris
from sklearn.linear_model import LogisticRegression 
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# %%
import pandas as pd

# %%
data=pd.read_csv(r"C:\Users\micro\Downloads\User_Data.csv")
data
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
data.head()
# Out:
#     User ID  Age  EstimatedSalary  Purchased  Gender_Male
# 0  15624510   19            19000          0            1
# 1  15810944   35            20000          0            1
# 2  15668575   26            43000          0            0
# 3  15603246   27            57000          0            0
# 4  15804002   19            76000          0            1

# %%
(data['Gender_Male']==1).sum()
(data['Gender_Male']==0).sum()
# Out:
# 204

# %%
data.Gender.value_counts()
# Out:
# Gender
# Female    204
# Male      196
# Name: count, dtype: int64

# %%
data=pd.get_dummies(data,columns=["Gender"],dtype=int,drop_first=True)
data
# Out:
#       User ID  Age  EstimatedSalary  Purchased  Gender_Male
# 0    15624510   19            19000          0            1
# 1    15810944   35            20000          0            1
# 2    15668575   26            43000          0            0
# 3    15603246   27            57000          0            0
# 4    15804002   19            76000          0            1
# ..        ...  ...              ...        ...          ...
# 395  15691863   46            41000          1            0
# 396  15706071   51            23000          1            1
# 397  15654296   50            20000          1            0
# 398  15755018   36            33000          0            1
# 399  15594041   49            36000          1            0
#
# [400 rows x 5 columns]

# %%
data
# Out:
#       User ID  Age  EstimatedSalary  Purchased  Gender_Male
# 0    15624510   19            19000          0            1
# 1    15810944   35            20000          0            1
# 2    15668575   26            43000          0            0
# 3    15603246   27            57000          0            0
# 4    15804002   19            76000          0            1
# ..        ...  ...              ...        ...          ...
# 395  15691863   46            41000          1            0
# 396  15706071   51            23000          1            1
# 397  15654296   50            20000          1            0
# 398  15755018   36            33000          0            1
# 399  15594041   49            36000          1            0
#
# [400 rows x 5 columns]

# %%
import seaborn as sns
sns.barplot(x="Age",y="EstimatedSalary",data=data)
# Out:
# <Axes: xlabel='Age', ylabel='EstimatedSalary'>

# %%
x=data.drop("Purchased",axis=1)
x
# Out:
#       User ID  Age  EstimatedSalary  Gender_Male
# 0    15624510   19            19000            1
# 1    15810944   35            20000            1
# 2    15668575   26            43000            0
# 3    15603246   27            57000            0
# 4    15804002   19            76000            1
# ..        ...  ...              ...          ...
# 395  15691863   46            41000            0
# 396  15706071   51            23000            1
# 397  15654296   50            20000            0
# 398  15755018   36            33000            1
# 399  15594041   49            36000            0
#
# [400 rows x 4 columns]

# %%
x.shape
# Out:
# (400, 4)

# %%
y=data.drop("Gender_Male",axis=1)
y
# Out:
#       User ID  Age  EstimatedSalary  Purchased
# 0    15624510   19            19000          0
# 1    15810944   35            20000          0
# 2    15668575   26            43000          0
# 3    15603246   27            57000          0
# 4    15804002   19            76000          0
# ..        ...  ...              ...        ...
# 395  15691863   46            41000          1
# 396  15706071   51            23000          1
# 397  15654296   50            20000          1
# 398  15755018   36            33000          0
# 399  15594041   49            36000          1
#
# [400 rows x 4 columns]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=101)

# %%
y.shape
# Out:
# (400, 4)

# %%
x.shape
# Out:
# (400, 4)

# %%
x_train.shape
# Out:
# (320, 4)

# %%
y_train.shape
# Out:
# (320, 4)

# %%
from sklearn.linear_model import LogisticRegression
log_model=LogisticRegression()
log_model
# Out:
# LogisticRegression()

# %%
data.head()
# Out:
#     User ID  Age  EstimatedSalary  Purchased  Gender_Male
# 0  15624510   19            19000          0            1
# 1  15810944   35            20000          0            1
# 2  15668575   26            43000          0            0
# 3  15603246   27            57000          0            0
# 4  15804002   19            76000          0            1

# %%
data.tail()
# Out:
#       User ID  Age  EstimatedSalary  Purchased  Gender_Male
# 395  15691863   46            41000          1            0
# 396  15706071   51            23000          1            1
# 397  15654296   50            20000          1            0
# 398  15755018   36            33000          0            1
# 399  15594041   49            36000          1            0

# %%
data.describe()
# Out:
#             User ID         Age  EstimatedSalary   Purchased  Gender_Male
# count  4.000000e+02  400.000000       400.000000  400.000000   400.000000
# mean   1.569154e+07   37.655000     69742.500000    0.357500     0.490000
# std    7.165832e+04   10.482877     34096.960282    0.479864     0.500526
# min    1.556669e+07   18.000000     15000.000000    0.000000     0.000000
# 25%    1.562676e+07   29.750000     43000.000000    0.000000     0.000000
# 50%    1.569434e+07   37.000000     70000.000000    0.000000     0.000000
# 75%    1.575036e+07   46.000000     88000.000000    1.000000     1.000000
# max    1.581524e+07   60.000000    150000.000000    1.000000     1.000000

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.4,random_state=100)
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
model
# Out:
# LogisticRegression()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.lmplot(x="Age",y="EstimatedSalary",data=data,scatter_kws={"color":'green' },line_kws={'color':"red"})
sns.set_style('whitegrid')
ax=plt.gca()
plt.gca()
plt.gca().set_facecolor('white')

# %%
data=pd.get_dummies(data,columns=["Gender_Male"],dtype=int,drop_first=True)
data
# Out:
#       User ID  Age  EstimatedSalary  Purchased  Gender_Male_1
# 0    15624510   19            19000          0              1
# 1    15810944   35            20000          0              1
# 2    15668575   26            43000          0              0
# 3    15603246   27            57000          0              0
# 4    15804002   19            76000          0              1
# ..        ...  ...              ...        ...            ...
# 395  15691863   46            41000          1              0
# 396  15706071   51            23000          1              1
# 397  15654296   50            20000          1              0
# 398  15755018   36            33000          0              1
# 399  15594041   49            36000          1              0
#
# [400 rows x 5 columns]

# %%
import numpy as np

# %%
#To check duplicate values
duplicate_rows=data.duplicated()
data[duplicate_rows].sum()
# Out:
# User ID            0
# Age                0
# EstimatedSalary    0
# Purchased          0
# Gender_Male_1      0
# dtype: int64

# %%
print("Before dropping duplicate:",data.shape)
data.drop_duplicates()
print("After dropping duplicate:",data.shape)
# Out:
# Before dropping duplicate: (400, 5)
# After dropping duplicate: (400, 5)

# %%
# Based on index value try to check the performance
response=data['Gender_Male_1']
response.dtype
# Out:
# dtype('int32')

# %%
sns.jointplot(x=response.index,y="Age",data=data,kind='hex')

# %%
sns.violinplot(response)
# Out:
# <Axes: ylabel='Gender_Male_1'>
